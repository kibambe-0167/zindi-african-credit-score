# %%
import pandas as pd


pd.set_option("display.max_column", 30)

# %%
df = pd.read_csv("./african-credit-scoring-challenge/economic_indicators.csv")
df
# Out:
#           Country                                          Indicator  \
# 0           Ghana              Inflation, consumer prices (annual %)
# 1   Cote d'Ivoire              Inflation, consumer prices (annual %)
# 2           Kenya              Inflation, consumer prices (annual %)
# 3           Ghana  Official exchange rate (LCU per US$, period av...
# 4   Cote d'Ivoire  Official exchange rate (LCU per US$, period av...
# 5           Kenya  Official exchange rate (LCU per US$, period av...
# 6           Ghana                             Real interest rate (%)
# 7   Cote d'Ivoire                             Real interest rate (%)
# 8           Kenya                             Real interest rate (%)
# 9           Ghana       Average precipitation in depth (mm per year)
# 10  Cote d'Ivoire       Average precipitation in depth (mm per year)
# 11          Kenya       Average precipitation in depth (mm per year)
# 12          Ghana                          Deposit interest rate (%)
# ...

# %%
kenya = df[df['Country'] == 'Kenya'].reset_index(drop=True)
kenya
# Out:
#   Country                                          Indicator      YR2001  \
# 0   Kenya              Inflation, consumer prices (annual %)    5.738598
# 1   Kenya  Official exchange rate (LCU per US$, period av...   78.563195
# 2   Kenya                             Real interest rate (%)   17.812501
# 3   Kenya       Average precipitation in depth (mm per year)  630.000000
# 4   Kenya                          Deposit interest rate (%)    6.639167
# 5   Kenya                          Lending interest rate (%)   19.665833
# 6   Kenya  Interest rate spread (lending rate minus depos...   13.026667
# 7   Kenya        Fossil fuel energy consumption (% of total)   16.421786
# 8   Kenya                                  Unemployment rate    2.868000
#
#        YR2002      YR2003      YR2004      YR2005      YR2006      YR2007  \
# 0    1.961308    9.815691   11.624036   10.312778   14.453734    9.758880
# 1   78.749142   75.935569   79.173876   75.554109   72.100835   67.317638
# ...

# %%
df['Indicator'].value_counts()
# Out:
# Indicator
# Inflation, consumer prices (annual %)                        3
# Official exchange rate (LCU per US$, period average)         3
# Real interest rate (%)                                       3
# Average precipitation in depth (mm per year)                 3
# Deposit interest rate (%)                                    3
# Lending interest rate (%)                                    3
# Interest rate spread (lending rate minus deposit rate, %)    3
# Fossil fuel energy consumption (% of total)                  3
# Unemployment rate                                            3
# Name: count, dtype: int64
